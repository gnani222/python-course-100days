# %% [markdown]
# # ***Python built-in data types***

# %% [markdown]
# <span style="color:orange;font-size: 16px; font-family: Arial; font-weight: bold;">Standard Data Types</span>
# - The data stored in memory can be of many types. For example, a person's age is stored as a numeric value and his or her address is stored as alphanumeric characters.
#
# - Python has various standard data types that are used to define the operations possible on them and the storage method for each of them.
#
# <span style="color:white;font-size: 16px; font-family: Arial; font-weight: bold;">Python has five standard data types:</span>
#
# - *Numbers*
# - *String*
# - *List*
# - *Tuple*
# - *Dictionary*

# %% [markdown]
# Number data types store numeric values. Number objects are created when you assign a value to them.

# %%
#This is integer datatype
a = 10
print(a)
a = 'ctug'
print(a)
print(type(a))
# Out:
# 10
# ctug
# <class 'str'>

# %%
# tis is float datatype
f = 10.0
print(type(f))
# Out:
# <class 'float'>

# %%
b,c,d,a = 11, 12, 13,89
print(a,b,c,d)
# Out:
# 89 11 12 13

# %% [markdown]
# ## Python Strings

# %% [markdown]
# - Strings in Python are identified as a contiguous set of characters represented in the quotation marks. Python allows either pair of single or double quotes.
#
# - Subsets of strings can be taken using the slice operator ([ ] and [:] ) with indexes starting at 0 in the beginning of the string and working their way from -1 to the end.
#
# - The plus (+) sign is the string concatenation operator and the asterisk (*) is the repetition operator.

# %%
statement = "      Python is a programming language      "

# %%
print(statement)
# Out:
#       Python is a programming language

# %%
print(type(statement)) #type is used to check the datatype
# Out:
# <class 'str'>

# %% [markdown]
# <span style="color:green;font-size: 20px; font-family: Arial; font-weight: italic;">*String Formatting*</span>

# %% [markdown]
# - Strings in Python can be formatted with the use of format() method which is very versatile and powerful tool for formatting of Strings.
#
# - Format method in String contains curly braces {} as placeholders which can hold arguments according to position or keyword to specify the order.
#
#
# Let's understand it with an example

# %%
string = "{} {} {}".format('Python','Programming','Language')
string
# Out:
# 'Python Programming Language'

# %% [markdown]
# Here in above code, three curly empty placeholders provided to add the words like Python, Programming and Language respectively. Similarly you can try fstring method as well as follows:

# %%
name = 'Priyanka'
course = 'Code Unnti Program 2.0'
print(f"Hello, My name is {name} and I registered for {course}")
# Out:
# Hello, My name is Priyanka and I registered for Code Unnti Program 2.0

# %% [markdown]
# - The idea behind f-strings is to make string interpolation simpler, to create an f-string, prefix the string with the letter “f ”.
# - The string itself can be formatted in much the same way that you would with str.format().
# - F-strings provide a concise and convenient way to embed python expressions inside string literals for formatting.

# %% [markdown]
# <span style="color:black;font-size: 16px; font-family: Arial; font-weight: bold;">String Slicing</span>

# %% [markdown]
# Syntax:
#
# str1[Start:End:Steps]

# %%
str1 = "FACeghjk"

# %% [markdown]
# ![r43tbrhs.png](attachment:r43tbrhs.png)

# %%
str1[5]
# Out:
# 'h'

# %%
str1 = "programming"
str1[3] = "g"
str1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 2
#       1 str1 = "programming"
# ----> 2 str1[3] = "g"
#       3 str1
#
# TypeError: 'str' object does not support item assignment

# %%
str1[::-1]
# Out:
# 'gnimmargorp'

# %% [markdown]
# ## **Python Lists**

# %% [markdown]
# - Lists are used to store multiple items in a single variable.
#
# - List are mutable datatypes(changeable).
#
# - Lists are created using square brackets
#
# - List items are ordered and allow duplicate values.
#
# - List items are indexed, the first item has index [0], the second item has index [1] etc.
#
# Let's create first list

# %%
#create list

list1 = ["parul", 22, "Bharat", 45.5, "vadodara", 99,True,[6,7]]
print(list1)

print(type(list1))
# Out:
# ['parul', 22, 'Bharat', 45.5, 'vadodara', 99, True, [6, 7]]
# <class 'list'>

# %%
list1[5] = 100 #access 1st position item from list
list1
# Out:
# ['parul', 22, 'Bharat', 45.5, 'vadodara', 100, True, [6, 7]]

# %%
list1[3] #access 4th position item from list#

#list1[start:end:step]
list1[0:5]
# Out:
# ['parul', 22, 'Bharat', 45.5, 'vadodara']

# %% [markdown]
# ## **Python Tuples**

# %% [markdown]
# - Tuples are Immutable datatypes(unchangeable)
# - A tuple is another sequence data type that is similar to the list.
# - A tuple consists of a number of values separated by commas. Unlike lists, however,
# - tuples are enclosed within parentheses.
#
# - The main differences between lists and tuples are: Lists are enclosed in brackets ([]) and their elements and size can be changed, while tuples are enclosed in parentheses (()) and cannot be updated.
# - Tuples can be thought of as read-only lists.
#
# Let's create first tuple

# %%
#create tuples -

tup1 = ("parul", 22, "Bharat", 45.5, "vadodara", 99)

print(tup1)
print(type(tup1))
# Out:
# ('parul', 22, 'Bharat', 45.5, 'vadodara', 99)
# <class 'tuple'>

# %%
tup1[4] # To access 5th item in tuple
# Out:
# 'vadodara'

# %%
tup1[2:4]
# Out:
# ('Bharat', 45.5)

# %%
tup1=("python", 87)
tup2 = ("php",)
tup3 = tup1 + tup2
print(tup3)
# Out:
# ('python', 87, 'php')

# %%
lst = list(tup3)
print(lst)
lst[1] = 'java'
tuple(lst)
# Out:
# ['python', 87, 'php']
# ('python', 'java', 'php')

# %%
#immutable 

del tup3[3]    #del is keyword used for deleting the items.
print(tup3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 3
#       1 #immutable
# ----> 3 del tup3[3]    #del is keyword used for deleting the items.
#       4 print(tup3)
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# ## **Python Dictionary**

# %% [markdown]
# - Dictionaries are used to store data values in key:value pairs.
# - Dictionaries are written with curly brackets, and have keys and values:

# %%
cars = {
  "brand": "Mahindra",
  "model": "Thar",
  "year": 2010
}
#{keys:values}

# %%
print(cars)
print(type(cars))
# Out:
# {'brand': 'Mahindra', 'model': 'Thar', 'year': 2010}
# <class 'dict'>

# %%
print(cars["model"]) #Accessing Items
# Out:
# Thar

# %% [markdown]
# ## **Python Sets**

# %% [markdown]
# The simple funcationality of set is it just ignores the duplicates in the set.
# Sets are:
# 1. Unordered
# 2. Unchangeable
# 3. Not allowed duplicate values

# %%
subjects = {'Physics', 'Hindi', 'Chemistry', 'maths', 'Hindi'}
print(subjects)
print(type(subjects))
# Out:
# {'Hindi', 'Chemistry', 'Physics', 'maths'}
# <class 'set'>

# %% [markdown]
# # **Python Boolean**

# %% [markdown]
# - True
# - False
#
# It is mainly used in decision-making and conditions in programing.

# %% [markdown]
# #### Example in python

# %%
a = True
b = False

print(a)
print(b)
# Out:
# True
# False

# %% [markdown]
# #### ***Uses of Boolean Data Type***
# - Used in if conditions
# - Used for comperissions
# - Controls programs flow
# ##### ***Example***

# %%
x = 10
y = 5
print(x>y) #True
print(x<y) # False
# Out:
# True
# False

# %% [markdown]
# - True means condition is correct.
# - False means condition is Wrong.
# - Boolean in written with capital first letters in Python.

# %% [markdown]
# ##### ***Real-Time-Example***

# %%
is_logged_in = True
has_permission = False

# %% [markdown]
# - <span style="color:red;font-size: 16px; font-family: serif; font-weight: bold;">is_logged_in</span> indicates  the user logged in.
# - <span style="color:red;font-size: 16px; font-family: serif; font-weight: bold;">has_permission</span> indicates user does not have permission.

# %% [markdown]
# #  **Python None Data Type**

# %% [markdown]
# - The None data type represents no value or empty value in Python.
# - None is a special constent in Python.
# - used when a variable has no value assinged.
# - It is not equal ti 0, False or empty string"".

# %%
name = None
if name is None:
    print("no value available")
# Out:
# no value available

# %%
student_photo = None
print(student_photo)
# Out:
# None
